# %%
import psycopg2

conn = psycopg2.connect(
    dbname="airquality",
    user="postgres",
    password="Milian112!",
    host="localhost",
    port=5432
)

cur = conn.cursor()
cur.execute("SELECT version();")
print(cur.fetchone())

conn.close()
